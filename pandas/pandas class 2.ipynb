# %%
# pandas :
# working with datasets :
# loading data through pandas

# %%
import pandas as pd

# %%
data=pd.read_csv("//home//chandan//Machine Learning//pandas//IPL_Ball_by_Ball_2022.csv")

# %%
data
# Out:
#             ID  innings  overs  ballnumber       batter          bowler  \
# 0      1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1      1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2      1312200        1      0           3   JC Buttler  Mohammed Shami
# 3      1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4      1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...        ...      ...    ...         ...          ...             ...
# 17907  1304047        2     17           5      SS Iyer        DJ Bravo
# 17908  1304047        2     17           6   SP Jackson        DJ Bravo
# 17909  1304047        2     18           1   SP Jackson        AF Milne
# 17910  1304047        2     18           2      SS Iyer        AF Milne
# 17911  1304047        2     18           3      SS Iyer        AF Milne
#
#        non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
# head()----> it returns top 5 rows from data set

# %%
data.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
data.head(10)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# 5  1312200        1      0           6  YBK Jaiswal  Mohammed Shami
# 6  1312200        1      1           1   JC Buttler      Yash Dayal
# 7  1312200        1      1           2   JC Buttler      Yash Dayal
# 8  1312200        1      1           3   JC Buttler      Yash Dayal
# 9  1312200        1      1           4   JC Buttler      Yash Dayal
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# ...

# %%
data.head(2)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
#
#   non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0  JC Buttler        NaN            0           0          0             0
# 1  JC Buttler    legbyes            0           1          1             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
# tail()-----> returns last rows from dataset

# %%
data.tail()
# Out:
#             ID  innings  overs  ballnumber      batter    bowler non-striker  \
# 17907  1304047        2     17           5     SS Iyer  DJ Bravo  SP Jackson
# 17908  1304047        2     17           6  SP Jackson  DJ Bravo     SS Iyer
# 17909  1304047        2     18           1  SP Jackson  AF Milne     SS Iyer
# 17910  1304047        2     18           2     SS Iyer  AF Milne  SP Jackson
# 17911  1304047        2     18           3     SS Iyer  AF Milne  SP Jackson
#
#       extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 17907        NaN            1           0          1             0
# 17908        NaN            1           0          1             0
# 17909        NaN            1           0          1             0
# 17910        NaN            2           0          2             0
# 17911        NaN            4           0          4             0
#
#        isWicketDelivery player_out kind fielders_involved  \
# ...

# %%
data.tail(7)
# Out:
#             ID  innings  overs  ballnumber       batter    bowler non-striker  \
# 17905  1304047        2     17           3  SW Billings  DJ Bravo     SS Iyer
# 17906  1304047        2     17           4   SP Jackson  DJ Bravo     SS Iyer
# 17907  1304047        2     17           5      SS Iyer  DJ Bravo  SP Jackson
# 17908  1304047        2     17           6   SP Jackson  DJ Bravo     SS Iyer
# 17909  1304047        2     18           1   SP Jackson  AF Milne     SS Iyer
# 17910  1304047        2     18           2      SS Iyer  AF Milne  SP Jackson
# 17911  1304047        2     18           3      SS Iyer  AF Milne  SP Jackson
#
#       extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 17905        NaN            0           0          0             0
# 17906        NaN            1           0          1             0
# 17907        NaN            1           0          1             0
# 17908        NaN            1           0          1             0
# ...

# %%
# random rows from data set

# %%
# sample()-----> returns random row from dataset

# %%
data.sample()
# Out:
#            ID  innings  overs  ballnumber   batter     bowler   non-striker  \
# 5643  1304097        2      1           1  WP Saha  JJ Bumrah  Shubman Gill
#
#      extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 5643        NaN            4           0          4             0
#
#       isWicketDelivery player_out kind fielders_involved     BattingTeam
# 5643                 0        NaN  NaN               NaN  Gujarat Titans

# %%
data.sample(3)
# Out:
#             ID  innings  overs  ballnumber    batter             bowler  \
# 6706   1304093        2     14           4  RK Singh           R Ashwin
# 6652   1304093        2      5           6    N Rana  M Prasidh Krishna
# 10804  1304076        2     13           5   VR Iyer           R Ashwin
#
#       non-striker extra_type  batsman_run  extras_run  total_run  \
# 6706       N Rana        NaN            1           0          1
# 6652      SS Iyer        NaN            0           0          0
# 10804     SS Iyer        NaN            1           0          1
#
#        non_boundary  isWicketDelivery player_out kind fielders_involved  \
# 6706              0                 0        NaN  NaN               NaN
# 6652              0                 0        NaN  NaN               NaN
# 10804             0                 0        NaN  NaN               NaN
#
#                  BattingTeam
# 6706   Kolkata Knight Riders
# 6652   Kolkata Knight Riders
# 10804  Kolkata Knight Riders

# %%
# info()----> information about dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17912 entries, 0 to 17911
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 17912 non-null  int64
#  1   innings            17912 non-null  int64
#  2   overs              17912 non-null  int64
#  3   ballnumber         17912 non-null  int64
#  4   batter             17912 non-null  object
#  5   bowler             17912 non-null  object
#  6   non-striker        17912 non-null  object
#  7   extra_type         1050 non-null   object
#  8   batsman_run        17912 non-null  int64
#  9   extras_run         17912 non-null  int64
#  10  total_run          17912 non-null  int64
#  11  non_boundary       17912 non-null  int64
#  12  isWicketDelivery   17912 non-null  int64
#  13  player_out         912 non-null    object
#  14  kind               912 non-null    object
#  15  fielders_involved  704 non-null    object
# ...

# %%
data.shape
# Out:
# (17912, 17)

# %%
# pandas------> anything extract from your dataset

# %%
# single coloumn extraction

# %%
data["bowler"]
# Out:
# 0        Mohammed Shami
# 1        Mohammed Shami
# 2        Mohammed Shami
# 3        Mohammed Shami
# 4        Mohammed Shami
#               ...
# 17907          DJ Bravo
# 17908          DJ Bravo
# 17909          AF Milne
# 17910          AF Milne
# 17911          AF Milne
# Name: bowler, Length: 17912, dtype: object

# %%
# dataframe-----> series-----> numpy array

# %%
bowlers=data["bowler"].values

# %%
bowlers
# Out:
# array(['Mohammed Shami', 'Mohammed Shami', 'Mohammed Shami', ...,
#        'AF Milne', 'AF Milne', 'AF Milne'], dtype=object)

# %%
# iloc-----> best extactin of dataset

# %%
# datasetname.iloc[rows,coloumns]

# %%
data.iloc[:,[4,5]]
# Out:
#             batter          bowler
# 0      YBK Jaiswal  Mohammed Shami
# 1      YBK Jaiswal  Mohammed Shami
# 2       JC Buttler  Mohammed Shami
# 3      YBK Jaiswal  Mohammed Shami
# 4      YBK Jaiswal  Mohammed Shami
# ...            ...             ...
# 17907      SS Iyer        DJ Bravo
# 17908   SP Jackson        DJ Bravo
# 17909   SP Jackson        AF Milne
# 17910      SS Iyer        AF Milne
# 17911      SS Iyer        AF Milne
#
# [17912 rows x 2 columns]

# %%
data.iloc[:11,[4,5]]
# Out:
#          batter          bowler
# 0   YBK Jaiswal  Mohammed Shami
# 1   YBK Jaiswal  Mohammed Shami
# 2    JC Buttler  Mohammed Shami
# 3   YBK Jaiswal  Mohammed Shami
# 4   YBK Jaiswal  Mohammed Shami
# 5   YBK Jaiswal  Mohammed Shami
# 6    JC Buttler      Yash Dayal
# 7    JC Buttler      Yash Dayal
# 8    JC Buttler      Yash Dayal
# 9    JC Buttler      Yash Dayal
# 10   JC Buttler      Yash Dayal

# %%
data.head(2)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
#
#   non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0  JC Buttler        NaN            0           0          0             0
# 1  JC Buttler    legbyes            0           1          1             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
data.iloc[50:100,1:5]
# Out:
#     innings  overs  ballnumber      batter
# 50        1      8           3  D Padikkal
# 51        1      8           4  D Padikkal
# 52        1      8           5  D Padikkal
# 53        1      8           6  D Padikkal
# 54        1      9           1  JC Buttler
# 55        1      9           2  JC Buttler
# 56        1      9           3  JC Buttler
# 57        1      9           4  JC Buttler
# 58        1      9           5  JC Buttler
# 59        1      9           6  JC Buttler
# 60        1     10           1  JC Buttler
# 61        1     10           2  JC Buttler
# 62        1     10           3  JC Buttler
# 63        1     10           4  D Padikkal
# 64        1     10           5  D Padikkal
# 65        1     10           6  D Padikkal
# 66        1     11           1  D Padikkal
# 67        1     11           2  JC Buttler
# 68        1     11           3  D Padikkal
# 69        1     11           4  JC Buttler
# 70        1     11           5  D Padikkal
# ...

# %%
data.head(2)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
#
#   non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0  JC Buttler        NaN            0           0          0             0
# 1  JC Buttler    legbyes            0           1          1             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
data.iloc[1,4:6]
# Out:
# batter       YBK Jaiswal
# bowler    Mohammed Shami
# Name: 1, dtype: object

# %%
# loc-------> return 1 row data ----> single row data extraction

# %%
data.loc[100]
# Out:
# ID                            1312200
# innings                             1
# overs                              16
# ballnumber                          5
# batter                        R Parag
# bowler                    LH Ferguson
# non-striker                  TA Boult
# extra_type                        NaN
# batsman_run                         1
# extras_run                          0
# total_run                           1
# non_boundary                        0
# isWicketDelivery                    0
# player_out                        NaN
# kind                              NaN
# fielders_involved                 NaN
# BattingTeam          Rajasthan Royals
# Name: 100, dtype: object

# %%
data.iloc[[9,10],:]
# Out:
#          ID  innings  overs  ballnumber      batter      bowler  non-striker  \
# 9   1312200        1      1           4  JC Buttler  Yash Dayal  YBK Jaiswal
# 10  1312200        1      1           5  JC Buttler  Yash Dayal  YBK Jaiswal
#
#    extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 9         NaN            0           0          0             0
# 10        NaN            1           0          1             0
#
#     isWicketDelivery player_out kind fielders_involved       BattingTeam
# 9                  0        NaN  NaN               NaN  Rajasthan Royals
# 10                 0        NaN  NaN               NaN  Rajasthan Royals

# %% [markdown]
# # self practice

# %%
dt=pd.read_csv("IPL_Matches_2022.csv")

# %%
dt
# Out:
#          ID       City        Date  Season  MatchNumber  \
# 0   1312200  Ahmedabad  2022-05-29    2022        Final
# 1   1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2   1312198    Kolkata  2022-05-25    2022   Eliminator
# 3   1312197    Kolkata  2022-05-24    2022  Qualifier 1
# 4   1304116     Mumbai  2022-05-22    2022           70
# ..      ...        ...         ...     ...          ...
# 69  1304051       Pune  2022-03-29    2022            5
# 70  1304050     Mumbai  2022-03-28    2022            4
# 71  1304049     Mumbai  2022-03-27    2022            3
# 72  1304048     Mumbai  2022-03-27    2022            2
# 73  1304047     Mumbai  2022-03-26    2022            1
#
#                           Team1                  Team2  \
# 0              Rajasthan Royals         Gujarat Titans
# 1   Royal Challengers Bangalore       Rajasthan Royals
# 2   Royal Challengers Bangalore   Lucknow Super Giants
# 3              Rajasthan Royals         Gujarat Titans
# ...

# %%
dt.head(5)
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29    2022        Final
# 1  1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25    2022   Eliminator
# 3  1312197    Kolkata  2022-05-24    2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22    2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
dt.tail()
# Out:
#          ID    City        Date  Season MatchNumber  \
# 69  1304051    Pune  2022-03-29    2022           5
# 70  1304050  Mumbai  2022-03-28    2022           4
# 71  1304049  Mumbai  2022-03-27    2022           3
# 72  1304048  Mumbai  2022-03-27    2022           2
# 73  1304047  Mumbai  2022-03-26    2022           1
#
#                           Team1                  Team2  \
# 69             Rajasthan Royals    Sunrisers Hyderabad
# 70         Lucknow Super Giants         Gujarat Titans
# 71  Royal Challengers Bangalore           Punjab Kings
# 72               Mumbai Indians         Delhi Capitals
# 73          Chennai Super Kings  Kolkata Knight Riders
#
#                                             Venue             TossWinner  \
# 69  Maharashtra Cricket Association Stadium, Pune    Sunrisers Hyderabad
# 70                       Wankhede Stadium, Mumbai         Gujarat Titans
# 71             Dr DY Patil Sports Academy, Mumbai           Punjab Kings
# ...

# %%
dt.sample()
# Out:
#          ID    City        Date  Season MatchNumber           Team1  \
# 50  1304070  Mumbai  2022-04-14    2022          24  Gujarat Titans
#
#                Team2                               Venue        TossWinner  \
# 50  Rajasthan Royals  Dr DY Patil Sports Academy, Mumbai  Rajasthan Royals
#
#    TossDecision SuperOver     WinningTeam WonBy  Margin  method  \
# 50        field         N  Gujarat Titans  Runs      37     NaN
#
#    Player_of_Match                                       Team1Players  \
# 50       HH Pandya  ['MS Wade', 'Shubman Gill', 'V Shankar', 'HH P...
#
#                                          Team2Players      Umpire1   Umpire2
# 50  ['JC Buttler', 'D Padikkal', 'R Ashwin', 'SV S...  CB Gaffaney  R Pandit

# %%
dt.sample(5)
# Out:
#          ID    City        Date  Season MatchNumber                Team1  \
# 12  1304108  Mumbai  2022-05-15    2022          62  Chennai Super Kings
# 69  1304051    Pune  2022-03-29    2022           5     Rajasthan Royals
# 42  1304078  Mumbai  2022-04-20    2022          32         Punjab Kings
# 56  1304064    Pune  2022-04-09    2022          18       Mumbai Indians
# 50  1304070  Mumbai  2022-04-14    2022          24       Gujarat Titans
#
#                           Team2  \
# 12               Gujarat Titans
# 69          Sunrisers Hyderabad
# 42               Delhi Capitals
# 56  Royal Challengers Bangalore
# 50             Rajasthan Royals
#
#                                             Venue  \
# 12                       Wankhede Stadium, Mumbai
# 69  Maharashtra Cricket Association Stadium, Pune
# 42                      Brabourne Stadium, Mumbai
# 56  Maharashtra Cricket Association Stadium, Pune
# 50             Dr DY Patil Sports Academy, Mumbai
#
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               74 non-null     int64
#  1   City             74 non-null     object
#  2   Date             74 non-null     object
#  3   Season           74 non-null     int64
#  4   MatchNumber      74 non-null     object
#  5   Team1            74 non-null     object
#  6   Team2            74 non-null     object
#  7   Venue            74 non-null     object
#  8   TossWinner       74 non-null     object
#  9   TossDecision     74 non-null     object
#  10  SuperOver        74 non-null     object
#  11  WinningTeam      74 non-null     object
#  12  WonBy            74 non-null     object
#  13  Margin           74 non-null     int64
#  14  method           0 non-null      float64
#  15  Player_of_Match  74 non-null     object
#  16  Team1Players     74 non-null     object
# ...

# %%
dt.shape
# Out:
# (74, 20)

# %%
dt["Team1"]
# Out:
# 0                Rajasthan Royals
# 1     Royal Challengers Bangalore
# 2     Royal Challengers Bangalore
# 3                Rajasthan Royals
# 4             Sunrisers Hyderabad
#                  ...
# 69               Rajasthan Royals
# 70           Lucknow Super Giants
# 71    Royal Challengers Bangalore
# 72                 Mumbai Indians
# 73            Chennai Super Kings
# Name: Team1, Length: 74, dtype: object

# %%
T1=dt["Team1"].values

# %%
T1
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Royal Challengers Bangalore', 'Rajasthan Royals',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Sunrisers Hyderabad',
#        'Delhi Capitals', 'Rajasthan Royals', 'Chennai Super Kings',
#        'Kolkata Knight Riders', 'Punjab Kings', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Gujarat Titans', 'Kolkata Knight Riders',
#        'Chennai Super Kings', 'Royal Challengers Bangalore',
#        'Lucknow Super Giants', 'Punjab Kings', 'Mumbai Indians',
#        'Delhi Capitals', 'Royal Challengers Bangalore', 'Gujarat Titans',
#        'Rajasthan Royals', 'Chennai Super Kings', 'Lucknow Super Giants',
#        'Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Sunrisers Hyderabad', 'Rajasthan Royals', 'Punjab Kings',
# ...

# %%
dt
# Out:
#          ID       City        Date  Season  MatchNumber  \
# 0   1312200  Ahmedabad  2022-05-29    2022        Final
# 1   1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2   1312198    Kolkata  2022-05-25    2022   Eliminator
# 3   1312197    Kolkata  2022-05-24    2022  Qualifier 1
# 4   1304116     Mumbai  2022-05-22    2022           70
# ..      ...        ...         ...     ...          ...
# 69  1304051       Pune  2022-03-29    2022            5
# 70  1304050     Mumbai  2022-03-28    2022            4
# 71  1304049     Mumbai  2022-03-27    2022            3
# 72  1304048     Mumbai  2022-03-27    2022            2
# 73  1304047     Mumbai  2022-03-26    2022            1
#
#                           Team1                  Team2  \
# 0              Rajasthan Royals         Gujarat Titans
# 1   Royal Challengers Bangalore       Rajasthan Royals
# 2   Royal Challengers Bangalore   Lucknow Super Giants
# 3              Rajasthan Royals         Gujarat Titans
# ...

# %%
dt.iloc[4,[5,6]]
# Out:
# Team1    Sunrisers Hyderabad
# Team2           Punjab Kings
# Name: 4, dtype: object

# %%
dt.iloc[65:70,[7,8]]
# Out:
#                                             Venue                   TossWinner
# 65             Dr DY Patil Sports Academy, Mumbai               Mumbai Indians
# 66                       Wankhede Stadium, Mumbai        Kolkata Knight Riders
# 67                      Brabourne Stadium, Mumbai         Lucknow Super Giants
# 68             Dr DY Patil Sports Academy, Mumbai  Royal Challengers Bangalore
# 69  Maharashtra Cricket Association Stadium, Pune          Sunrisers Hyderabad

# %%
dt.loc[2]
# Out:
# ID                                                           1312198
# City                                                         Kolkata
# Date                                                      2022-05-25
# Season                                                          2022
# MatchNumber                                               Eliminator
# Team1                                    Royal Challengers Bangalore
# Team2                                           Lucknow Super Giants
# Venue                                          Eden Gardens, Kolkata
# TossWinner                                      Lucknow Super Giants
# TossDecision                                                   field
# SuperOver                                                          N
# WinningTeam                              Royal Challengers Bangalore
# WonBy                                                           Runs
# Margin                                                            14
# ...

# %% [markdown]
# # another problem question

# %%
dt=pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
dt
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
dt.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
dt["customerID"]
# Out:
# 0       7590-VHVEG
# 1       5575-GNVDE
# 2       3668-QPYBK
# 3       7795-CFOCW
# 4       9237-HQITU
#            ...
# 7038    6840-RESVB
# 7039    2234-XADUH
# 7040    4801-JZAZL
# 7041    8361-LTMKD
# 7042    3186-AJIEK
# Name: customerID, Length: 7043, dtype: object

# %%
ss=dt["customerID"].values

# %%
ss
# Out:
# array(['7590-VHVEG', '5575-GNVDE', '3668-QPYBK', ..., '4801-JZAZL',
#        '8361-LTMKD', '3186-AJIEK'], dtype=object)

# %%
dx=pd.Series(ss)

# %%
dx
# Out:
# 0       7590-VHVEG
# 1       5575-GNVDE
# 2       3668-QPYBK
# 3       7795-CFOCW
# 4       9237-HQITU
#            ...
# 7038    6840-RESVB
# 7039    2234-XADUH
# 7040    4801-JZAZL
# 7041    8361-LTMKD
# 7042    3186-AJIEK
# Length: 7043, dtype: object

# %%
fx=pd.DataFrame({
    'customer ID':dx
})

# %%
fx
# Out:
#      customer ID
# 0     7590-VHVEG
# 1     5575-GNVDE
# 2     3668-QPYBK
# 3     7795-CFOCW
# 4     9237-HQITU
# ...          ...
# 7038  6840-RESVB
# 7039  2234-XADUH
# 7040  4801-JZAZL
# 7041  8361-LTMKD
# 7042  3186-AJIEK
#
# [7043 rows x 1 columns]
