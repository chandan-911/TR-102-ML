# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("placements_new.csv")

# %%
data.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x=data["cgpa"].values.reshape(200,1)
y=data["package"].values.reshape(200,1)

# %%
x
# Out:
# array([[6.89],
#        [5.12],
#        [7.82],
#        [7.42],
#        [6.94],
#        [7.89],
#        [6.73],
#        [6.75],
#        [6.09],
#        [8.31],
#        [5.32],
#        [6.61],
#        [8.94],
#        [6.93],
#        [7.73],
#        [7.25],
#        [6.84],
#        [5.38],
#        [6.94],
#        [7.48],
#        [7.28],
#        [6.85],
#        [6.14],
#        [6.19],
#        [6.53],
#        [7.28],
#        [8.31],
#        [5.42],
#        [5.94],
#        [7.15],
#        [7.36],
#        [8.1 ],
#        [6.96],
#        [6.35],
#        [7.34],
#        [6.87],
#        [5.99],
#        [5.9 ],
#        [8.62],
#        [7.43],
#        [9.38],
#        [6.89],
#        [5.95],
#        [7.66],
#        [5.09],
#        [7.87],
#        [6.07],
#        [5.84],
#        [8.63],
#        [8.87],
#        [9.58],
#        [9.26],
#        [8.37],
#        [6.47],
#        [6.86],
#        [8.2 ],
#        [5.84],
#        [6.6 ],
# ...

# %%
y
# Out:
# array([[3.26],
#        [1.98],
#        [3.25],
#        [3.67],
#        [3.57],
#        [2.99],
#        [2.6 ],
#        [2.48],
#        [2.31],
#        [3.51],
#        [1.86],
#        [2.6 ],
#        [3.65],
#        [2.89],
#        [3.42],
#        [3.23],
#        [2.35],
#        [2.09],
#        [2.98],
#        [2.83],
#        [3.16],
#        [2.93],
#        [2.3 ],
#        [2.48],
#        [2.71],
#        [3.65],
#        [3.42],
#        [2.16],
#        [2.24],
#        [3.49],
#        [3.26],
#        [3.89],
#        [3.08],
#        [2.73],
#        [3.42],
#        [2.87],
#        [2.84],
#        [2.43],
#        [4.36],
#        [3.33],
#        [4.02],
#        [2.7 ],
#        [2.54],
#        [2.76],
#        [1.86],
#        [3.58],
#        [2.26],
#        [3.26],
#        [4.09],
#        [4.62],
#        [4.43],
#        [3.79],
#        [4.11],
#        [2.61],
#        [3.09],
#        [3.39],
#        [2.74],
#        [1.94],
# ...

# %%
plt.scatter(x,y,color="green")
plt.xlabel("CGPA")
plt.ylabel("Package")
plt.title("Placements of students")
# Out:
# Text(0.5, 1.0, 'Placements of students')

# %%
# train_test_split
#     to break data in 2 parts
# 1. training data --> to train model
# 2. testing data --> to test data

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)
# 20% data will used for test

# %%
# x --> (200,1) 
# xtrain --> 80% (160)
# xtest --> 20%  (40)

# %%
xtrain.shape
# Out:
# (160, 1)

# %%
xtest.shape
# Out:
# (40, 1)

# %%
plt.scatter(xtrain,ytrain,color="green",label=("training data"))
plt.scatter(xtest,ytest,color="red",label=("testing data"))
plt.legend()

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred=model.predict(xtest)

# %%
ypred
# Out:
# array([[1.77466809],
#        [3.66380182],
#        [2.97265533],
#        [2.81714737],
#        [3.28367126],
#        [4.1303257 ],
#        [3.09360597],
#        [2.07992445],
#        [3.1281633 ],
#        [1.93017605],
#        [2.70771585],
#        [2.97841489],
#        [2.46581458],
#        [2.10296267],
#        [4.31463143],
#        [3.22607571],
#        [2.51765056],
#        [2.60980343],
#        [4.12456615],
#        [2.38518082],
#        [3.07632731],
#        [2.51189101],
#        [3.08784642],
#        [2.43125725],
#        [2.94961712],
#        [3.09936552],
#        [3.56012985],
#        [2.9265789 ],
#        [4.49893717],
#        [2.89202158],
#        [2.88626202],
#        [3.08208686],
#        [2.49461235],
#        [3.69259959],
#        [2.37366171],
#        [2.65012031],
#        [2.63284164],
#        [2.67891808],
#        [3.3412668 ],
#        [2.7768305 ]])

# %%
ytest
# Out:
# array([[1.54],
#        [3.6 ],
#        [2.46],
#        [2.82],
#        [3.34],
#        [3.65],
#        [3.03],
#        [2.09],
#        [2.83],
#        [2.01],
#        [2.61],
#        [3.57],
#        [2.58],
#        [2.16],
#        [3.79],
#        [3.08],
#        [2.3 ],
#        [2.73],
#        [3.91],
#        [2.6 ],
#        [2.66],
#        [2.19],
#        [2.93],
#        [2.84],
#        [2.7 ],
#        [3.49],
#        [4.14],
#        [3.44],
#        [4.43],
#        [3.08],
#        [3.11],
#        [2.99],
#        [2.2 ],
#        [3.76],
#        [2.57],
#        [2.01],
#        [2.09],
#        [2.72],
#        [3.4 ],
#        [2.21]])

# %%
plt.scatter(xtrain,ytrain,color="lightblue",label="model train")
plt.plot(xtest,ypred,color="green",linestyle="dashdot",label="model pridiction")
plt.xlabel("independent variable")
plt.ylabel("dependent variable")
plt.title("SLR Model")
plt.grid()
plt.legend()
