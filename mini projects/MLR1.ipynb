# %%
import numpy as np
import pandas as pd
import plotly.express as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# loading datasets
data=pd.read_csv("Student_Performance.csv")

# %%
data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0
#
# [10000 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
x=data.drop(columns=["Extracurricular Activities","Performance Index"])

# %%
x
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced
# 0                                    1
# 1                                    2
# 2                                    2
# 3                                    2
# 4                                    5
# ...                                ...
# 9995                                 2
# 9996                                 5
# 9997                                 5
# 9998                                 0
# 9999                                 1
#
# [10000 rows x 4 columns]

# %%
y=data["Performance Index"]
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
# divide data into two parts
x_train , x_test , y_train , y_test =train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (8000, 4)

# %%
x_test.shape
# Out:
# (2000, 4)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# -33.67999054268262

# %%
model.coef_
# Out:
# array([2.84903782, 1.01829398, 0.47651234, 0.1891704 ])

# %%
# formula used
# y=b0+b1x1+b2x2+b3x3+b4x4

# %%
x_train.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Sleep Hours',
#        'Sample Question Papers Practiced'],
#       dtype='object')

# %%
x_test.head(2)
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 2387              8               91            6
# 1701              5               95            9
#
#       Sample Question Papers Practiced
# 2387                                 7
# 1701                                 4

# %%
y_test
# Out:
# 2387    85.0
# 1701    84.0
# 5221    56.0
# 2513    75.0
# 2586    62.0
#         ...
# 411     20.0
# 4773    58.0
# 5113    63.0
# 1216    56.0
# 5802    20.0
# Name: Performance Index, Length: 2000, dtype: float64

# %%
y=(-33.90514199698804)+(2.85134042*3)+(1.01951539*83)+(0.48704094*5)+(0.2006063*5)
y
# Out:
# 62.70689283301196

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([85.96033133, 82.3484196 , 55.5325494 , ..., 61.53750425,
#        56.97632182, 20.16766256])

# %%
import joblib

# %%
joblib.dump(model,"student_result_predictor.joblib")
# Out:
# ['student_result_predictor.joblib']
